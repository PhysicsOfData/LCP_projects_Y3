# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.linalg as la
import pywt
from numpy import fft
from scipy import signal
from matplotlib.ticker import AutoMinorLocator, MultipleLocator, FuncFormatter

# %% [markdown]
# ## Loadings od Data

# %%
DF = pd.read_csv('4_Chest_sweater.txt',sep='\t')
sample_f = DF['Log Freq'][0]
DF['Time'] = np.arange(0, len(DF['AccX']) )/sample_f    #changed freq
DF
# Out:
#        Log Mode  Log Freq   Timestamp     AccX     AccY     AccZ      GyroX  \
# 0             5       100  1555414552  687.836  380.823  580.354  -7.926829
# 1             5       100  1555414552 -812.703 -108.946  726.876 -11.707320
# 2             5       100  1555414552 -812.520 -108.824  733.952 -37.073170
# 3             5       100  1555414552 -787.144  -45.628  616.954 -56.341460
# 4             5       100  1555414552 -800.259 -137.433  411.689  -1.097561
# ...         ...       ...         ...      ...      ...      ...        ...
# 14933         5       100  1555415471 -890.722  -81.008  446.764  -2.682927
# 14934         5       100  1555415471 -885.964  -76.006  459.025  -3.902439
# 14935         5       100  1555415471 -879.681  -77.714  475.068  -3.048780
# 14936         5       100  1555415471 -894.992  -76.311  502.701   0.121951
# 14937         5       100  1555415471 -889.319  -90.951  471.835   3.536585
#
#             GyroY      GyroZ  MagnX  MagnY  MagnZ        qw        qi  \
# 0        8.048780   0.975610   -592    122   -113  0.788006  0.002899
# 1      -81.829270   8.780488    125     60   -128  0.183978 -0.428877
# 2     -145.487800  14.756100    123     59   -136  0.128994 -0.427229
# 3     -174.634200  23.048780    118     58   -145  0.113618 -0.421033
# 4       37.073170   1.341463    113     57   -157  0.107202 -0.424787
# ...           ...        ...    ...    ...    ...       ...       ...
# 14933    2.926829   0.365854    144     47    -50  0.017279  0.534410
# 14934    3.292683   0.365854    146     45    -51  0.016416  0.535050
# 14935    2.804878   0.365854    144     46    -54  0.015920  0.534349
# 14936    1.463415   0.609756    144     45    -53  0.015192  0.531663
# 14937    0.853659   0.609756    144     45    -53  0.015803  0.530137
#
#              qj        qk    Time
# 0     -0.432874 -0.437788    0.00
# 1      0.002594  0.884426    0.01
# 2      0.000702  0.894894    0.02
# 3     -0.001770  0.899899    0.03
# 4     -0.001251  0.898923    0.04
# ...         ...       ...     ...
# 14933  0.040437 -0.844081  149.33
# 14934  0.041231 -0.843654  149.34
# 14935  0.041780 -0.844081  149.35
# 14936  0.041749 -0.845790  149.36
# 14937  0.041749 -0.846736  149.37
#
# [14938 rows x 17 columns]

# %% [markdown]
# ## Select the interesting features

# %%
fig, ax = plt.subplots()
ax.plot(DF['AccX'])
ax.set_xlabel('index')
ax.set_ylabel('AccX')
plt.show()

# %%
a = 2500
b = 12500
df = DF.iloc[a:b+1]    
df = df.drop(['Log Mode', 'Log Freq', 'Timestamp','qw', 'qi', 'qj', 'qk'], axis=1)  
df
# Out:
#           AccX     AccY     AccZ     GyroX     GyroY     GyroZ  MagnX  MagnY  \
# 2500  -817.583  -97.844  591.151 -4.512195  3.780488  0.121951    128     53
# 2501  -804.590  -89.182  605.913 -2.317073  3.292683 -0.243902    127     51
# 2502  -818.559  -90.646  607.011 -1.585366  0.000000  0.121951    126     50
# 2503  -805.810  -91.439  603.290 -2.682927  0.731707  0.609756    127     50
# 2504  -810.629 -100.040  582.184 -1.097561  2.926829  0.487805    128     51
# ...        ...      ...      ...       ...       ...       ...    ...    ...
# 12496 -799.466  -77.958  602.192 -2.073171  0.487805  0.731707    123     47
# 12497 -795.135  -78.141  615.734 -2.439024  0.121951  0.365854    121     46
# 12498 -795.074  -81.923  623.115 -2.195122  0.487805  0.121951    121     47
# 12499 -798.978  -84.241  632.814 -2.317073  1.219512  0.243902    124     48
# 12500 -802.272  -88.511  612.318 -2.439024  1.341463  0.365854    122     46
#
#        MagnZ    Time
# 2500    -113   25.00
# 2501    -113   25.01
# 2502    -112   25.02
# 2503    -114   25.03
# 2504    -112   25.04
# ...      ...     ...
# 12496   -117  124.96
# 12497   -116  124.97
# 12498   -116  124.98
# 12499   -118  124.99
# 12500   -119  125.00
#
# [10001 rows x 10 columns]

# %% [markdown]
# ## Calibration

# %%
gyro_off = np.array([-2.804399, 1.793105, 0.3411708])
acc_cal = np.array([[1.002982, 9.415505E-05, 0.004346743],
                    [9.04459E-05, 1.002731, -0.001444198], 
                    [0.004346536, -0.001444751,	1.030587]])
acc_off = np.array([3.602701, -20.96658, 54.97186])
magn_cal=np.array([[1.013437, -0.04728858, -0.001861475], 
                    [-0.04728862, 1.004832, 0.008222118],    
                    [-0.001861605, 0.008221965, 0.9439077]])
magn_off=np.array([-150.4098, 74.62431, 630.9805])

# %%
df[['GyroX','GyroY','GyroZ']]=df[['GyroX','GyroY','GyroZ']]+gyro_off.T
df[['AccX','AccY','AccZ']]=np.dot(df[['AccX','AccY','AccZ']],acc_cal.T)+acc_off.T
df[['MagnX','MagnY','MagnZ']]=np.dot(df[['MagnX','MagnY','MagnZ']],magn_cal.T)+magn_off.T
df
# Out:
#              AccX        AccY        AccZ     GyroX     GyroY     GyroZ  \
# 2500  -813.857963 -120.005478  660.792102 -7.316594  5.573593  0.463122
# 2501  -800.761235 -111.339966  676.049587 -5.121472  5.085788  0.097268
# 2502  -814.767256 -112.810814  677.122570 -4.389765  1.793105  0.463122
# 2503  -801.996487 -113.599452  673.344316 -5.487326  2.524812  0.950927
# 2504  -806.922410 -122.193896  651.584227 -3.901960  4.719934  0.828976
# ...           ...         ...         ...       ...       ...       ...
# 12496 -795.637073 -100.079476  672.220829 -4.877570  2.280910  1.072878
# 12497 -791.234311 -100.282142  686.196127 -5.243423  1.915056  0.707024
# 12498 -791.141402 -104.085124  693.808619 -4.999521  2.280910  0.463122
# 12499 -795.015103 -106.423815  703.790662 -5.121472  3.012617  0.585073
# 12500 -798.408419 -110.676174  682.659603 -5.243423  3.134568  0.707024
#
#            MagnX       MagnY       MagnZ    Time
# 2500  -22.985812  120.898363  524.516409   25.00
# 2501  -23.904672  118.935988  524.501826   25.01
# 2502  -24.872682  117.986667  525.439374   25.02
# 2503  -23.855522  117.922934  523.549697   25.03
# 2504  -22.893096  118.896921  525.443872   25.04
# ...          ...         ...         ...     ...
# 12496 -27.761820  115.072926  520.700754  124.96
# 12497 -29.743267  114.170893  521.640163  124.97
# 12498 -29.790555  115.175725  521.648385  124.98
# 12499 -26.793810  116.022247  519.763207  124.99
# 12500 -28.724245  114.098938  518.806578  125.00
#
# [10001 rows x 10 columns]

# %% [markdown]
# ## Descrittive statistics

# %%
stat_df = pd.DataFrame({
    'mean'  : df.mean(),
    'median': df.median(),
    'variance': df.var(),
    'standard deviation': df.std(),
    '25% percentile' : df.quantile(q=0.25),
    '75% percentile': df.quantile(q=0.75)
    }).T
stat_df.drop(['Time'], axis=1)
# Out:
#                           AccX        AccY        AccZ     GyroX     GyroY  \
# mean               -781.303663  -93.000182  709.985107 -5.630494  3.304734
# median             -779.137681  -93.058513  712.570307 -5.609277  3.256520
# variance            164.959067  158.748301  410.642127  0.634556  0.836360
# standard deviation   12.843639   12.599536   20.264307  0.796590  0.914527
# 25% percentile     -789.595916 -102.844146  697.208329 -6.097082  2.768715
# 75% percentile     -771.860406  -82.925857  724.270962 -5.121472  3.866276
#
#                        GyroZ      MagnX       MagnY       MagnZ
# mean                0.621387 -34.094530  110.521105  511.925778
# median              0.585073 -34.786252  110.381876  511.194350
# variance            0.057051  16.201442   16.214815   29.094141
# standard deviation  0.238854   4.025101    4.026762    5.393898
# 25% percentile      0.463122 -37.355539  107.369424  508.366350
# 75% percentile      0.828976 -31.653226  113.312061  515.018227

# %% [markdown]
# ## Centers Data

# %%
dfc = df - stat_df.iloc[0]
dfc['Time'] = df['Time']
dfc
# Out:
#             AccX       AccY       AccZ     GyroX     GyroY     GyroZ  \
# 2500  -32.554300 -27.005296 -49.193005 -1.686100  2.268859 -0.158265
# 2501  -19.457573 -18.339784 -33.935520  0.509022  1.781054 -0.524118
# 2502  -33.463593 -19.810632 -32.862537  1.240729 -1.511629 -0.158265
# 2503  -20.692825 -20.599270 -36.640791  0.143168 -0.779922  0.329540
# 2504  -25.618747 -29.193714 -58.400880  1.728534  1.415200  0.207589
# ...          ...        ...        ...       ...       ...       ...
# 12496 -14.333410  -7.079294 -37.764278  0.752924 -1.023824  0.451491
# 12497  -9.930649  -7.281960 -23.788980  0.387071 -1.389678  0.085638
# 12498  -9.837740 -11.084942 -16.176488  0.630973 -1.023824 -0.158265
# 12499 -13.711441 -13.423633  -6.194444  0.509022 -0.292117 -0.036313
# 12500 -17.104756 -17.675992 -27.325504  0.387071 -0.170166  0.085638
#
#            MagnX      MagnY      MagnZ    Time
# 2500   11.108718  10.377258  12.590631   25.00
# 2501   10.189858   8.414883  12.576049   25.01
# 2502    9.221848   7.465562  13.513596   25.02
# 2503   10.239008   7.401829  11.623919   25.03
# 2504   11.201434   8.375816  13.518095   25.04
# ...          ...        ...        ...     ...
# 12496   6.332710   4.551821   8.774977  124.96
# 12497   4.351263   3.649788   9.714385  124.97
# 12498   4.303975   4.654620   9.722607  124.98
# 12499   7.300720   5.501142   7.837429  124.99
# 12500   5.370285   3.577833   6.880801  125.00
#
# [10001 rows x 10 columns]

# %% [markdown]
# ## PCA

# %%
N = dfc.shape[0]

#Acc
U_acc,D_diag_acc,_=la.svd(dfc[['AccX','AccY','AccZ']].T)
avl_acc = np.real_if_close(D_diag_acc)**2/(N-1)
avl_acc_n = avl_acc/avl_acc.sum()

#Gyro
U_gyro,D_diag_gyro,_=la.svd(dfc[['GyroX','GyroY','GyroZ']].T)
avl_gyro = np.real_if_close(D_diag_gyro)**2/(N-1)
avl_gyro_n = avl_gyro/avl_gyro.sum()

#Magn
U_magn,D_diag_magn,_=la.svd(dfc[['MagnX','MagnY','MagnZ']].T)
avl_magn = np.real_if_close(D_diag_magn)**2/(N-1)
avl_magn_n = avl_magn/avl_magn.sum()

#Plot
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15,5))
ax1.plot(np.arange(U_acc.shape[0])+1, avl_acc_n, color = 'blue', marker = 'o')
ax1.set_title('Acc')
ax1.set_xlabel('# eigenvalue')
ax1.set_ylabel('eigenvalue')
ax1.xaxis.set_major_locator(MultipleLocator(1.000))
ax2.plot(np.arange(U_gyro.shape[0])+1, avl_gyro_n, color = 'orange', marker = 'o')
ax2.set_title('Gyro')
ax2.set_xlabel('# eigenvalue')
ax2.set_ylabel('eigenvalue')
ax2.xaxis.set_major_locator(MultipleLocator(1.000))
ax3.plot(np.arange(U_magn.shape[0])+1, avl_magn_n, color = 'green', marker = 'o')
ax3.set_title('Magn')
ax3.set_xlabel('# eigenvalue')
ax3.set_ylabel('eigenvalue')
ax3.xaxis.set_major_locator(MultipleLocator(1.000))
plt.show()

# %%
rot=np.dot(dfc[['AccX','AccY','AccZ']],U_acc)
rot1=np.dot(dfc[['GyroX','GyroY','GyroZ']],U_gyro)
rot2=np.dot(dfc[['MagnX','MagnY','MagnZ']],U_magn)
dfr=pd.DataFrame({'acc_PCA1': rot[:,0], 'acc_PCA2': rot[:,1],'acc_PCA3': rot[:,2],
                  'gyro_PCA1': rot1[:,0], 'gyro_PCA2': rot1[:,1],'gyro_PCA3': rot1[:,2],
                  'magn_PCA1': rot2[:,0], 'magn_PCA2': rot2[:,1],'magn_PCA3': rot2[:,2]})
dfr['Time']=dfc['Time'].values
dfr
# Out:
#         acc_PCA1   acc_PCA2  acc_PCA3  gyro_PCA1  gyro_PCA2  gyro_PCA3  \
# 0      64.672169  -3.738352 -3.543375   2.821415  -0.043443   0.231142
# 1      43.194385  -0.593565 -0.676087   1.165550  -1.484791  -0.377947
# 2      49.020895 -10.574243 -8.795272  -1.914265  -0.062306  -0.425660
# 3      46.843800  -0.850408  0.075860  -0.744696   0.359159   0.231959
# 4      69.922291   4.997683  2.269880   0.042640  -2.234272   0.199812
# ...          ...        ...       ...        ...        ...        ...
# 9996   39.184927  10.564826 -5.884698  -1.320590   0.023250   0.272867
# 9997   26.284924   4.675636 -2.191232  -1.337542   0.538774  -0.095228
# 9998   21.838756  -1.812139  1.058646  -1.163365   0.124210  -0.320228
# 9999   16.596477 -11.429937  0.694374  -0.531370  -0.225551  -0.111927
# 10000  36.650073  -2.829242  0.681262  -0.378764  -0.203950   0.032507
#
#        magn_PCA1  magn_PCA2  magn_PCA3    Time
# 0     -19.668360   1.557351   0.587674   25.00
# 1     -18.232577  -0.065473   0.607715   25.01
# 2     -17.920822  -1.486840  -0.166737   25.02
# 3     -17.108548  -0.266931   1.402208   25.03
# 4     -19.410458  -0.567153   1.130376   25.04
# ...          ...        ...        ...     ...
# 9996  -11.678477  -1.160037   0.299995  124.96
# 9997  -10.852226  -2.653586  -1.345879  124.97
# 9998  -11.312870  -1.878266  -1.791611  124.98
# 9999  -11.990231   0.261329   1.074448  124.99
# 10000  -9.376567  -0.859815   0.571827  125.00
#
# [10001 rows x 10 columns]

# %% [markdown]
# ## Signal Analysis

# %%
x = dfr['acc_PCA1']
y = dfc['AccY']
z = dfc['AccZ']
g = dfr['gyro_PCA1']
m = dfr['magn_PCA1']
t = dfr['Time']

# %%
n = 3
coeffs_x = pywt.wavedec(x, 'bior5.5', level = n)
sigs = np.zeros((n+1,len(t)+1))
for i in range(n+1):
    ca = coeffs_x.copy()
    for j in range(n+1):
        if j != i: 
            ca[j] = np.zeros_like(ca[j])
    sigs[i] = pywt.waverec(ca, 'bior5.5')

ax = []
fig, ax = plt.subplots(nrows = n+1, ncols = 1, figsize = (10, 5))
for i in range(n+1):
    ax[i].plot(t, sigs[i][:-1], color = 'red')

# %%
ca = coeffs_x.copy()
for j in range(n+1):
    if (j!=1) & (j!=2): 
        ca[j] = np.zeros_like(ca[j])
sigx_w = pywt.waverec(ca, 'bior5.5')
plt.plot(t, (sigx_w[:-1]), color = 'red')
plt.xlim(30, 40)
# Out:
# (30.0, 40.0)

# %%
n = 3
coeffs_y = pywt.wavedec(y, 'bior5.5', level = n)
sigs = np.zeros((n+1,len(t)+1))
for i in range(n+1):
    ca = coeffs_y.copy()
    for j in range(n+1):
        if j != i: 
            ca[j] = np.zeros_like(ca[j])
    sigs[i] = pywt.waverec(ca, 'bior5.5')

ax = []
fig, ax = plt.subplots(nrows = n+1, ncols = 1, figsize = (10, 5))
for i in range(n+1):
    ax[i].plot(t, sigs[i][:-1], color = 'red')

# %%
ca = coeffs_y.copy()
for j in range(n+1):
    if (j!=1) & (j!=2): 
        ca[j] = np.zeros_like(ca[j])
sigy_w = pywt.waverec(ca, 'bior5.5')
plt.plot(t, (sigy_w[:-1]), color = 'red')
plt.xlim(30, 40)
# Out:
# (30.0, 40.0)

# %%
n = 3
coeffs_z = pywt.wavedec(z, 'bior5.5', level = n)
sigs = np.zeros((n+1,len(t)+1))
for i in range(n+1):
    ca = coeffs_z.copy()
    for j in range(n+1):
        if j != i: 
            ca[j] = np.zeros_like(ca[j])
    sigs[i] = pywt.waverec(ca, 'bior5.5')

ax = []
fig, ax = plt.subplots(nrows = n+1, ncols = 1, figsize = (10, 5))
for i in range(n+1):
    ax[i].plot(t, sigs[i][:-1], color = 'red')

# %%
# %matplotlib inline
ca = coeffs_z.copy()
for j in range(n+1):
    if (j!=1) & (j!=2): 
        ca[j] = np.zeros_like(ca[j])
sigz_w = pywt.waverec(ca, 'bior5.5')
plt.plot(t, (sigz_w[:-1]), color = 'red')
plt.xlim(30, 40)
# Out:
# (30.0, 40.0)

# %%
SIG = (sigx_w**2)**0.5    
plt.figure(figsize=(20,10))
plt.plot(t, SIG[:-1])
plt.xlim(30, 40)
# Out:
# (30.0, 40.0)

# %%
SIG_h = signal.hilbert(SIG)
plt.figure(figsize=(20,10))
plt.plot(t, SIG[:-1])
plt.plot(t, np.abs(SIG_h[:-1]))
plt.xlim(30, 40)
# Out:
# (30.0, 40.0)

# %%
# %matplotlib inline
b, a = signal.butter(4, Wn=[0.67/50, 6/50], btype='bandpass')
filtered_data_butterworth = signal.filtfilt(b, a, np.abs(SIG))
filtered_data_butterworth_2 = signal.filtfilt(b, a, np.abs(SIG_h))
plt.figure(figsize=(20,10))
plt.plot(t, filtered_data_butterworth[:-1])
plt.plot(t, filtered_data_butterworth_2[:-1])
plt.xlim(30, 45)
# Out:
# (30.0, 45.0)

# %% [markdown]
# # PEAKS FIND

# %%
def histo_func(bins1,peaks1,t):
    from matplotlib.gridspec import GridSpec
    from lmfit.models import GaussianModel
    peaks_time1=t[peaks1]
    period1 = peaks_time1[1:]-peaks_time1[:-1]
    rate1 = 1/period1*60

    fig = plt.figure(figsize=(12,6))
    gs = GridSpec(3,3)

    ax_main = fig.add_subplot(gs[:,:2])
    ax_marg = fig.add_subplot(gs[:,2])
    ax_main.plot((peaks_time1[1:]+peaks_time1[:-1])*0.5,rate1,'r-o')
    ax_main.set_xlabel('Time (s)')
    ax_main.set_ylabel('Heart BPM')
    ax_main.set_title('Heart BPM as a function of time and histogram')
    l=ax_main.get_ylim()
    h1,b1,_=ax_marg.hist(x=rate1, bins=bins1,orientation='horizontal', color='red')
    bin_center1=(b1[1:]+b1[:-1])*0.5
    ax_marg.set_ylim(l)

    mod1 = GaussianModel(prefix='g_')
    pars1 = mod1.guess(h1, x=bin_center1)
    out1 = mod1.fit(h1, pars1, x=bin_center1)
    #print(out.params)
    #ax_marg.plot(out.best_fit, bin_center, 'r-', label='best fit')
    print(out1.params['g_center'].value, out1.params['g_center'].stderr)
    print(out1.params['g_sigma'].value, out1.params['g_sigma'].stderr)

# %%
data=filtered_data_butterworth_2[:-1]

# %%
from imp import reload
# %matplotlib inline
plt.figure(figsize=(13,5))
plt.plot(t,dfc['AccZ'], color='grey',alpha=0.4)
plt.plot(t,data)
peaks1,_ = signal.find_peaks(data, height=0.3 , distance=50,threshold=None, prominence=None)
#print(peaks)
plt.plot(t[peaks1],data[peaks1], 'rx')
plt.ylim(-20,40)
#peaks2,_=signal.find_peaks(-data, height=6, distance=55)
#plt.plot(t[peaks2],data[peaks2], 'gx')
# Out:
# (-20.0, 40.0)

# %%
histo_func(20,peaks1,t.values)
# Out:
# 75.43194876947192 1.4983997887832186
# 9.809054901975447 1.4988242014677566

# %% [markdown]
# ### Try to fix the result

# %%
def fix2(time,peaks,data,thr,r=0.5):
    
    peaks_time=time[peaks]
    period = peaks_time[1:]-peaks_time[:-1]
    rate = 1/period*60
    
    peaks_new=peaks.copy()
    diff_mean=np.mean(np.abs(period[1:]-period[:-1]))
    for i in np.arange(1,len(period)-1):
        
        if np.abs(period[i]-period[i+1])>2*(diff_mean):
            new_thr=0.33*(thr+data[peaks[i+1]])
            if period[i]-period[i+1]>0:
                array=data[(time<time[peaks[i+1]]) & (time>time[peaks[i+1]]-r)]
                der = array[1:]-array[:-1]
                change=[]
                for d in range(len(der)-1):
                    if der[d]>0 and der[d+1]<0 and array[d+1]>new_thr: change=np.append(change,d+1)
                if len(change)>0:
                    peaks_new[i+1]= peaks[i+1]-len(array)+change[-1]
                
            if period[i]-period[i+1]<0: #
                array=data[(time>time[peaks[i+1]]) & (time<time[peaks[i+1]]+r)]
                der = array[1:]-array[:-1]
                change=np.array([])
                for d in range(len(der)-1):
                    if der[d]>0 and der[d+1]<0 and array[d+1]>new_thr: change=np.append(change,d+1)
                if len(change)>0:
                    peaks_new[i+1]= peaks[i+1] + change[0] +1
                
    plt.figure(figsize=(10,4))
    plt.plot(time,data)
    #plt.plot(time,high_sign,color='grey',alpha=0.5)
    plt.plot(time[peaks],data[peaks], 'rx', label='old peaks')
    plt.plot(time[peaks_new],data[peaks_new], 'gx', label='new peaks')
    plt.legend()
    return peaks_new

# %%
def fix_add(time,peaks,data,ratio,r=0.5):
    
    peaks_time=time[peaks]
    period = peaks_time[1:]-peaks_time[:-1]
    rate = 1/period*60    
    
    peaks_new=peaks.copy()
    diff_mean=np.mean(np.abs(period[1:]-period[:-1]))
    ad=0   #how many added points
    for i in np.arange(1,len(period)-1):
        
        if period[i]/period[i+1]>ratio:
            maxima=np.array([])
            y=data[peaks_new[i-ad]:peaks_new[i+1-ad]]
            der = y[1:]-y[:-1] 

            for d in range(len(der)-1):
                if der[d]>0 and der[d+1]<0 : 
                    maxima=np.append(maxima,d+1)
                
            mean=(peaks_new[i+1-ad]-peaks[i-ad])*0.5
            dist=np.abs(maxima-mean)
            new_index=maxima[np.argmin(dist)]
            new_p=peaks_new[i-ad]+new_index
            peaks_new=np.append(peaks_new,0)
            peaks_temp=peaks_new.copy()
            peaks_new[i+2-ad:]=peaks_temp[i+1-ad:-1]
            peaks_new[i+1-ad]=np.int(new_p)
            ad+=1
        
                
    plt.figure(figsize=(10,4))
    plt.plot(time,data)
    #plt.plot(time,high_sign,color='grey',alpha=0.5)
    plt.plot(time[peaks_new],data[peaks_new], 'gx', label='added peak')
    plt.plot(time[peaks],data[peaks], 'rx',label='unmodified peaks')
    plt.legend()
    return peaks_new,ad

# %%
peaks1_new=fix2(time=t.values,peaks=peaks1,data=data,thr=0.,r=0.4)

# %%
histo_func(20,peaks1_new,t.values)
# Out:
# 76.97620413412137 1.2796673978586761
# 9.778369138899555 1.279806931636303

# %%
peaks1_new_new,added=fix_add(t.values,peaks1_new,data,ratio=1.8,r=0.5)
print(added)
# Out:
# 1

# %%
histo_func(25,peaks1_new_new,t.values)
# Out:
# 77.03050572998751 0.8985126995113678
# 9.003836354290979 0.9021473678831461
